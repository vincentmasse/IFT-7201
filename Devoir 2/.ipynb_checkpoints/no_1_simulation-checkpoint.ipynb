# %%
from poutyne import Model
from copy import deepcopy  # NEW
from scipy.stats import bernoulli

import numpy as np
import gym
import torch
import random


from collections import deque

class ReplayBuffer:
    def __init__(self, buffer_size):
        self.__buffer_size = buffer_size
        # TODO : Add any needed attributes
        self.data = deque(maxlen=int(buffer_size))

    def store(self, element):
        """
        Stores an element. If the replay buffer is already full, deletes the oldest
        element to make space.
        """
        # TODO : Implement
        self.data.append(element)
        pass

    def get_batch(self, batch_size):
        """
        Returns a list of batch_size elements from the buffer.
        """
        buffer_list = list(self.data)
        return random.sample(buffer_list, batch_size)


class DQN(Model):
    def __init__(self, actions, *args, **kwargs):
        self.actions = actions
        super().__init__(*args, **kwargs)

    def get_action(self, state, epsilon):
        """
        Returns the selected action according to an epsilon-greedy policy.
        """
        # TODO: implement
        if bernoulli.rvs(epsilon):
            action = random.choice(self.actions)
        else:
            pred_r = self.predict(state)
            action = self.actions[np.argmax(pred_r)]
        return action


    def soft_update(self, other, tau):
        """
        Code for the soft update between a target network (self) and
        a source network (other).

        The weights are updated according to the rule in the assignment.
        """
        new_weights = {}

        own_weights = self.get_weight_copies()
        other_weights = other.get_weight_copies()

        for k in own_weights:
            new_weights[k] = (1 - tau) * own_weights[k] + tau * other_weights[k]

        self.set_weights(new_weights)


class NNModel(torch.nn.Module):
    """
    Neural Network with 3 hidden layers of hidden dimension 64.
    """

    def __init__(self, in_dim, out_dim, n_hidden_layers=3, hidden_dim=64):
        super().__init__()
        layers = [torch.nn.Linear(in_dim, hidden_dim), torch.nn.ReLU()]
        for _ in range(n_hidden_layers - 1):
            layers.extend([torch.nn.Linear(hidden_dim, hidden_dim), torch.nn.ReLU()])
        layers.append(torch.nn.Linear(hidden_dim, out_dim))

        self.fa = torch.nn.Sequential(*layers)

    def forward(self, x):
        return self.fa(x)


def format_batch(batch, target_network, gamma):
    """
    Input : 
        - batch, a list of n=batch_size elements from the replay buffer
        - target_network, the target network to compute the one-step lookahead target
        - gamma, the discount factor

    Returns :
        - states, a numpy array of size (batch_size, state_dim) containing the states in the batch
        - (actions, targets) : where actions and targets both
                      have the shape (batch_size, ). Actions are the 
                      selected actions according to the target network
                      and targets are the one-step lookahead targets.
    """
    # TODO: Implement

    states = np.array([x[0] for x in batch])
    actions_taken = np.array([x[1] for x in batch])
    rewards = np.array([x[2] for x in batch])
    next_states = np.array([x[3] for x in batch])
    terminal = np.array([x[4] for x in batch])

    next_qvals_predicted = target_network.predict(next_states)

    next_actions_vals_selected = np.max(next_qvals_predicted, axis=1)

    targets = rewards + gamma * next_actions_vals_selected * (1 - terminal)

    act_targ = (actions_taken.astype(np.int64), targets.astype(np.float32))

    return states, act_targ


def dqn_loss(y_pred, y_target):
    """
    Input :
        - y_pred, (batch_size, n_actions) Tensor outputted by the network
        - y_target = (actions, targets), where actions and targets both
                      have the shape (batch_size, ). Actions are the 
                      selected actions according to the target network
                      and targets are the one-step lookahead targets.

    Returns :
        - The DQN loss 
    """
    # C'est essentiellement le même travail que ce qui est fait dans update_theta
    # sauf (1) qu'on le fait en PyTorch et les fonctions n'ont pas le même nom
    # et (2) on ne calcule pas le gradient nous-mêmes, on fait juste donner la perte.
    # C'est PyTorch qui fait la descente de gradient pour nous.

    actions, targets = y_target
    q_pred = y_pred.gather(1, actions.unsqueeze(-1)).squeeze()

    return torch.nn.functional.mse_loss(q_pred, targets)

def set_random_seed(environment, seed):
    environment.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)  # NEW


def run_dqn(agent):
    environment = gym.make("LunarLander-v2")
    set_random_seed(environment, seed=42)

    env = gym.wrappers.Monitor(environment, "demo", force=True)

    done = False
    s = environment.reset().astype(np.float32)
    while not done:
        env.render()
        q_vals = agent.predict(s)
        action = np.argmax(q_vals)
        next_s, r, done, _ = environment.step(action)

        s = next_s.astype(np.float32)
    env.close()

# %%
# NEW : Added lr argument
def main(batch_size, gamma, buffer_size, seed, tau, training_interval, lr):
    environment = gym.make("LunarLander-v2")
    set_random_seed(environment, seed)

    actions = list(range(environment.action_space.n))
    model = NNModel(environment.observation_space.shape[0], environment.action_space.n)
    policy_net = DQN(
        actions,
        model,
        optimizer=torch.optim.Adam(model.parameters(), lr=lr),
        loss_function=dqn_loss,
    )
    # NEW: pass a deep copy of the model
    target_net = DQN(actions, deepcopy(model), optimizer="sgd", loss_function=dqn_loss,)
    replay_buffer = ReplayBuffer(buffer_size)

    training_done = False
    episodes_done = 0
    steps_done = 0
    epsilon = 1.0
    epsilon_decay = 0.9
    epsilon_min = 0.01
    n = 10 # Nombre d'épisodes succès de suite à avoir pour que l'apprentissage arrête
    G_liste = [] #Pour emmagasiner le gain cumulé après chaque épisode
    loss_liste = [] #Pour emmagasiner la perte après chaque épisode

    while not training_done:
        s = environment.reset()
        episode_done = False
        G = 0
        while not episode_done:
            a = policy_net.get_action(s, epsilon)
            next_s, r, episode_done, _ = environment.step(a)
            replay_buffer.store((s, a, r, next_s, episode_done))
            s = next_s
            steps_done += 1
            G += r

            if steps_done % training_interval == 0:
                if len(replay_buffer.data) >= batch_size:
                    batch = replay_buffer.get_batch(batch_size)
                    x, y = format_batch(batch, target_net, gamma)
                    loss = policy_net.train_on_batch(x, y)
                    target_net.soft_update(policy_net, tau)

        # TODO: update epsilon
        epsilon = max(epsilon * epsilon_decay, epsilon_min)
        
        episodes_done += 1
        
        G_liste.append(G)
        loss_liste.append(loss)
        
        if episodes_done > n and np.min(G_liste[-n:]) >= 200:
            training_done = True

        if (episodes_done) % 10 == 0:
            print(f"After {episodes_done} trajectoires, we have G_0 = {G:.2f}, {epsilon:4f}")

    return policy_net, G_liste, loss_liste, episodes_done

# %%
if __name__ == "__main__":
    """
    All hyperparameter values and overall code structure are
    only given as a baseline. 
    
    You can use them if they help  you, but feel free to implement
    from scratch the required algorithms if you wish !
    """
    batch_size = 32
    gamma = 0.99
    buffer_size = 1e5
    seed = 42
    tau = 1e-2
    training_interval = 4
    lr = 5e-4  # NEW lr as parameter

    # NEW : pass lr to main()
    dqn, Gains, Loss, n_episodes = main(batch_size, gamma, buffer_size, seed, tau, training_interval, lr)
# Out:
# After 10 trajectoires, we have G_0 = -234.45, 0.348678
# After 20 trajectoires, we have G_0 = -475.24, 0.121577
# After 30 trajectoires, we have G_0 = -184.69, 0.042391
# After 40 trajectoires, we have G_0 = -487.27, 0.014781
# After 50 trajectoires, we have G_0 = -168.28, 0.010000
# After 60 trajectoires, we have G_0 = -139.87, 0.010000
# After 70 trajectoires, we have G_0 = -112.30, 0.010000
# After 80 trajectoires, we have G_0 = -118.59, 0.010000
# After 90 trajectoires, we have G_0 = -160.44, 0.010000
# After 100 trajectoires, we have G_0 = -184.92, 0.010000
# After 110 trajectoires, we have G_0 = -340.03, 0.010000
# After 120 trajectoires, we have G_0 = -256.88, 0.010000
# After 130 trajectoires, we have G_0 = -268.88, 0.010000
# After 140 trajectoires, we have G_0 = -219.47, 0.010000
# After 150 trajectoires, we have G_0 = -261.78, 0.010000
# After 160 trajectoires, we have G_0 = -7.12, 0.010000
# After 170 trajectoires, we have G_0 = -154.98, 0.010000
# After 180 trajectoires, we have G_0 = -259.78, 0.010000
# After 190 trajectoires, we have G_0 = -144.77, 0.010000
# After 200 trajectoires, we have G_0 = -165.70, 0.010000
# After 210 trajectoires, we have G_0 = -104.27, 0.010000
# After 220 trajectoires, we have G_0 = -101.81, 0.010000
# After 230 trajectoires, we have G_0 = -102.23, 0.010000
# After 240 trajectoires, we have G_0 = -110.65, 0.010000
# After 250 trajectoires, we have G_0 = -112.72, 0.010000
# After 260 trajectoires, we have G_0 = -81.49, 0.010000
# After 270 trajectoires, we have G_0 = -45.83, 0.010000
# After 280 trajectoires, we have G_0 = -12.65, 0.010000
# After 290 trajectoires, we have G_0 = -119.78, 0.010000
# After 300 trajectoires, we have G_0 = -34.26, 0.010000
# After 310 trajectoires, we have G_0 = -146.39, 0.010000
# After 320 trajectoires, we have G_0 = -50.94, 0.010000
# After 330 trajectoires, we have G_0 = -133.33, 0.010000
# After 340 trajectoires, we have G_0 = -30.59, 0.010000
# After 350 trajectoires, we have G_0 = -24.55, 0.010000
# After 360 trajectoires, we have G_0 = -72.54, 0.010000
# After 370 trajectoires, we have G_0 = -38.22, 0.010000
# After 380 trajectoires, we have G_0 = 4.80, 0.010000
# After 390 trajectoires, we have G_0 = 5.96, 0.010000
# After 400 trajectoires, we have G_0 = -78.73, 0.010000
# After 410 trajectoires, we have G_0 = -32.63, 0.010000
# After 420 trajectoires, we have G_0 = 10.17, 0.010000
# After 430 trajectoires, we have G_0 = -87.84, 0.010000
# After 440 trajectoires, we have G_0 = -6.25, 0.010000
# After 450 trajectoires, we have G_0 = 25.40, 0.010000
# After 460 trajectoires, we have G_0 = -60.92, 0.010000
# After 470 trajectoires, we have G_0 = -70.62, 0.010000
# After 480 trajectoires, we have G_0 = -44.33, 0.010000
# After 490 trajectoires, we have G_0 = -59.66, 0.010000
# After 500 trajectoires, we have G_0 = -172.61, 0.010000
# After 510 trajectoires, we have G_0 = -60.18, 0.010000
# After 520 trajectoires, we have G_0 = -55.34, 0.010000
# After 530 trajectoires, we have G_0 = -76.54, 0.010000
# After 540 trajectoires, we have G_0 = -24.69, 0.010000
# After 550 trajectoires, we have G_0 = -11.61, 0.010000
# After 560 trajectoires, we have G_0 = -46.25, 0.010000
# After 570 trajectoires, we have G_0 = -12.37, 0.010000
# After 580 trajectoires, we have G_0 = -46.38, 0.010000
# After 590 trajectoires, we have G_0 = -29.50, 0.010000
# After 600 trajectoires, we have G_0 = -26.17, 0.010000
# After 610 trajectoires, we have G_0 = -23.24, 0.010000
# After 620 trajectoires, we have G_0 = -89.29, 0.010000
# After 630 trajectoires, we have G_0 = -13.80, 0.010000
# After 640 trajectoires, we have G_0 = -78.80, 0.010000
# After 650 trajectoires, we have G_0 = -81.76, 0.010000
# After 660 trajectoires, we have G_0 = -3.80, 0.010000
# After 670 trajectoires, we have G_0 = -44.24, 0.010000
# After 680 trajectoires, we have G_0 = -10.14, 0.010000
# After 690 trajectoires, we have G_0 = -61.61, 0.010000
# After 700 trajectoires, we have G_0 = 20.32, 0.010000
# After 710 trajectoires, we have G_0 = -44.62, 0.010000
# After 720 trajectoires, we have G_0 = -37.80, 0.010000
# After 730 trajectoires, we have G_0 = -43.74, 0.010000
# After 740 trajectoires, we have G_0 = -43.32, 0.010000
# After 750 trajectoires, we have G_0 = -51.92, 0.010000
# After 760 trajectoires, we have G_0 = 10.29, 0.010000
# After 770 trajectoires, we have G_0 = -21.43, 0.010000
# After 780 trajectoires, we have G_0 = -47.78, 0.010000
# After 790 trajectoires, we have G_0 = 17.44, 0.010000
# After 800 trajectoires, we have G_0 = -26.59, 0.010000
# After 810 trajectoires, we have G_0 = 38.16, 0.010000
# After 820 trajectoires, we have G_0 = -11.01, 0.010000
# After 830 trajectoires, we have G_0 = -17.56, 0.010000
# After 840 trajectoires, we have G_0 = -14.35, 0.010000
# After 850 trajectoires, we have G_0 = 8.18, 0.010000
# After 860 trajectoires, we have G_0 = -5.46, 0.010000
# After 870 trajectoires, we have G_0 = 37.90, 0.010000
# After 880 trajectoires, we have G_0 = -24.12, 0.010000
# After 890 trajectoires, we have G_0 = -28.02, 0.010000
# After 900 trajectoires, we have G_0 = -30.74, 0.010000
# After 910 trajectoires, we have G_0 = -9.18, 0.010000
# After 920 trajectoires, we have G_0 = 99.95, 0.010000
# After 930 trajectoires, we have G_0 = -25.21, 0.010000
# After 940 trajectoires, we have G_0 = 130.14, 0.010000
# After 950 trajectoires, we have G_0 = 20.98, 0.010000
# After 960 trajectoires, we have G_0 = -12.75, 0.010000
# After 970 trajectoires, we have G_0 = 241.20, 0.010000
# After 980 trajectoires, we have G_0 = 154.14, 0.010000
# After 990 trajectoires, we have G_0 = 248.85, 0.010000
# After 1000 trajectoires, we have G_0 = 249.78, 0.010000
# After 1010 trajectoires, we have G_0 = 226.91, 0.010000
# After 1020 trajectoires, we have G_0 = 21.88, 0.010000
# After 1030 trajectoires, we have G_0 = 205.10, 0.010000
# After 1040 trajectoires, we have G_0 = 201.52, 0.010000
# After 1050 trajectoires, we have G_0 = 207.59, 0.010000
# After 1060 trajectoires, we have G_0 = 208.73, 0.010000
# After 1070 trajectoires, we have G_0 = 169.05, 0.010000
# After 1080 trajectoires, we have G_0 = 190.56, 0.010000
# After 1090 trajectoires, we have G_0 = 178.17, 0.010000
# After 1100 trajectoires, we have G_0 = 291.81, 0.010000
# After 1110 trajectoires, we have G_0 = 226.16, 0.010000
# After 1120 trajectoires, we have G_0 = -123.72, 0.010000
# After 1130 trajectoires, we have G_0 = 261.43, 0.010000

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (8,8)

# %%
plt.plot(range(n_episodes), Gains, color='green')
plt.xlabel('épisodes')
plt.ylabel('Gains')
plt.title('somme des récompenses (gain) selon les épisodes')
plt.savefig("gains.pdf", bbox_inches='tight')
plt.show()
plt.plot(range(n_episodes), Loss, color='red')
plt.xlabel('épisodes')
plt.ylabel('pertes')
plt.title('fonctions de pertes selon les épisodes')
plt.savefig("pertes.pdf", bbox_inches='tight')
plt.show()

# %%
run_dqn(dqn)
